# %% [markdown]
# <a href="https://colab.research.google.com/github/mypage-shivangi/Page-View-Time-Series-Visualizer/blob/main/Page_View_Time_Series_Visualizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/mypage-shivangi/Page-View-Time-Series-Visualizer"
# Out:
# Cloning into 'Page-View-Time-Series-Visualizer'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 10 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (10/10), 10.45 KiB | 2.09 MiB/s, done.

# %%
# %cd Page-View-Time-Series-Visualizer
# Out:
# /content/Page-View-Time-Series-Visualizer

# %%
# !ls
# Out:
# fcc-forum-pageviews.csv  README.md	   test_module.py
# main.py			 requirements.txt  time_series_visualizer.py

# %%
# !python main.py
# Out:
# /content/Page-View-Time-Series-Visualizer/time_series_visualizer.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['year','month'])['value']
# Figure(1500x700)
# Figure(1500x700)
# Figure(1500x700)
# /content/Page-View-Time-Series-Visualizer/time_series_visualizer.py:43: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['year','month'])['value']
# Figure(1500x700)
# ...

# %%
import matplotlib.pyplot as plt
import time_series_visualizer as tsv

fig1 = tsv.draw_line_plot()
plt.show()

fig2 = tsv.draw_bar_plot()
plt.show()

fig3 = tsv.draw_box_plot()
plt.show()
# Out:
# /content/Page-View-Time-Series-Visualizer/time_series_visualizer.py:44: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   .groupby(['year','month'])['value']
